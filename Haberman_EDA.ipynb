# %% [markdown]
# <a href="https://colab.research.google.com/github/ajnasaju3/ai/blob/master/Haberman_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-b76e394f-aa46-4cc2-a0d7-dcecbe744467" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b76e394f-aa46-4cc2-a0d7-dcecbe744467">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving haberman.csv to haberman.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
haberman=pd.read_csv('haberman.csv')
haberman
# Out:
#      30  64   1  1.1
# 0    30  62   3    1
# 1    30  65   0    1
# 2    31  59   2    1
# 3    31  65   4    1
# 4    33  58  10    1
# ..   ..  ..  ..  ...
# 300  75  62   1    1
# 301  76  67   0    1
# 302  77  65   3    1
# 303  78  65   1    2
# 304  83  58   2    2
#
# [305 rows x 4 columns]

# %%
haberman.columns
# Out:
# Index(['30', '64', '1', '1.1'], dtype='object')

# %%
haberman.columns=['age','year','node','survival_status']

# %%
print(haberman.shape)
# Out:
# (305, 4)

# %%
haberman.columns
# Out:
# Index(['age', 'year', 'node', 'survival_status'], dtype='object')

# %%
haberman['survival_status'].value_counts()
# Out:
# 1    224
# 2     81
# Name: survival_status, dtype: int64

# %%
haberman.plot(kind='scatter',x='age',y='year')
plt.show()

# %%
sns.FacetGrid(haberman,hue='survival_status').map(plt.scatter,'age','year').add_legend()
plt.show()

# %%
sns.pairplot(haberman,hue='survival_status')
plt.show()

# %%
sns.FacetGrid(haberman,hue='survival_status').map(sns.distplot,'age').add_legend()

# %%
sns.FacetGrid(haberman,hue='survival_status').map(sns.distplot,'year').add_legend()

# %%
sns.FacetGrid(haberman,hue='survival_status').map(sns.distplot,'node').add_legend()

# %%
clss1=haberman.loc[haberman['survival_status']==1]
sns.boxplot(x='survival_status',y='age',data=haberman)
plt.show()
